# %%
from collections import defaultdict
f = open("input10-2.txt", "r")
l = f.read().split("\n")[:-1]
ll = [x for x in l]

print(ll)
# Out:
# ['<([<({{[<{{((<()>({}{})}<({}<>)>)}}>[<{(([()<>]<<>{}>))}<{({<>[]}<<>>)[([]<>)<{}{}>]}>>]]}}[<[{{[{{[<><>]', '[<{{{[((({<<<[()[]]{()()}><{<><>}(<>{})>><<{<><>}{{}[]}>{(()())[[]{}]}>>{[[(<>[]){<>{}}][(()())(()[])]]', '(((<{<[[<[{(((<><>)[{}{}]){{{}<>}[()<>]})(([<>()][<>{}]){{[]()}})}[({([][])<{}<>>}{[[]<>]{()', '[(<{<[<<<<[[{<[]()><<>()>}[{{}<>}<()>]]<<[[]{}]>{({}())}>]((((<>())<(){}>)<{[]{}}<(){}>>)[{[[]<>]<[', '[[{(<{<<[{(<({<>{}}<()[]>){<<>[]>{<>}}><[[()[]]]{{()<>}{()<>}}])[{[(<>())]<<[]{}>(<>[])>}<[{', '(<<<[[<{({<<([{}{}](<><>)){{<><>}(())}>{<{(){}}{[][]}>[{[][]}([]())]}><([{{}[]}[[]{}]](<[]{}><{}<>>))((<(){', '<<<{((<<{[([<[[]{}]([][])>{[<>()][[][]]}]<<[()[]][[]{}]>[<<><>>(<><>)]>)<({{{}<>}{{}}}{{<><', '{[(<[{{{<[{({([]{}){{}{}}}[({}<>)])[([()[]]<[]{}>)<[{}{}]{{}()}>]}(<{{{}<>}(()[])}>{{<()<>><[]<>>}', '[<<{({[{((({<<<><>>(()())>{{[][]}<{}()>}}[[((){})[{}()]]<[()<>]>]){{(<{}<>>[()<>]){{[][]}(()<>', '({[([([<(<<[{<<><>>({}())}[[(){}][[][]]]]>><<(({<><>}{[][]})<{()()}[[]<>]>)[{((
# ...

# %%
def check(e,c,d):
    if e == c and e != d:
        return False
    return True

# %%
left = 0 
right = len(ll)-1
ct = 0
for x in ll:
    openList=[]
    
    for i in range(0,len(x)-1):
        if x[i] in ["(","<","{","["]:
            openList.append(x[i])
        if x[i] in [")",">","}","]"]:    
            t = openList[-1]
            #print(openList)
            if x[i] == ")" and t != "(":
                print(t,x[i])
                ct+=3
                break
            elif x[i] == ")" and t == "(":
                openList.pop()
            if x[i] == ">" and t != "<":
                print(t,x[i])
                ct+=25137
                break
            elif x[i] == ">" and t == "<":
                openList.pop()
            if x[i] == "}" and t != "{":
                print(t,x[i])
                ct+=1197
                break
            elif x[i] == "}" and t == "{":
                openList.pop()
            if x[i] == "]" and t != "[":
                print(t,x[i])
                ct+= 57
                break
            elif x[i] == "]" and t == "[":
                openList.pop()
                
print(ct)
# Out:
# ( }
# < ]
# { )
# ( >
# { >
# [ >
# < )
# { >
# [ )
# < }
# < )
# [ }
# < ]
# < )
# ( ]
# < ]
# ( }
# < }
# ( ]
# [ >
# ( }
# ( >
# < )
# { >
# { )
# < }
# { )
# { >
# { ]
# [ }
# < )
# [ >
# ( }
# { )
# { ]
# [ }
# { )
# [ >
# { )
# [ >
# ( ]
# ( }
# { >
# ( }
# { >
# < }
# { ]
# [ }
# [ >
# < }
# { )
# < }
# < }
# { >
# < }
# 399153
